# %%
import pde
import numpy as np
import h5py

import matplotlib.pyplot as plt

from IPython.display import Video

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-18a98cfbbb88> in <cell line: 1>()
# ----> 1 arctan(0)
#
# NameError: name 'arctan' is not defined

# %%
## DEFINE EQUATION TO SIMULATE ##

# Gaussian Potential

w0 = 1                      # omega for harmonic potential
m = 1                       # mass
mu0 = -3                    # center of initial gaussian wave-packet
hbar = 1                    # reduced plank constant

A = 100                       # Gaussian potential depth
Lambda = 1                  # Constant for gaussian potential
sigma = 1                   # Parameter for gaussian potential

a = 1                       # Parameter for arctan potential   

# Gaussian
#eq = pde.PDE({'psi':f'I*0.5*laplace(psi)/{m} - (0.5*{m}*{w0**2}*x**2)*I*psi - ({A}*exp(-{Lambda}*x**2))*I*psi'})

# Arctan
eq = pde.PDE({'psi':f'I*0.5*laplace(psi)/{m} - (0.5*{m}*{w0**2}*x**2)*I*psi - (1/{a}*simpy.arctan({a}*x))*I*psi'})

## DEFINE SPATIAL GRID ##

Nx = 1000 # number of spatial points
x_left = -10
x_right = 10

grid = pde.CartesianGrid([(x_left,x_right)], Nx, periodic=False)

dx = grid.discretization
x = grid.cell_coords.flatten()

## DEFINE INITIAL STATE ##

const = 1/(2*np.pi*sigma**2)**(1/4)
psi0 = const*np.exp(-(x-mu0)**2/(4*sigma**2))

initial_state = pde.ScalarField(grid=grid, data=psi0, label='psi')

initial_state.plot(scalar='norm_squared') # TODO: ADD LABELS 

print("Total Probability: ", np.sum(np.abs(initial_state.data)**2)*dx)

# Potential V(x)

#V = (A*np.exp(-Lambda*x**2))                    # Gaussian
V = (1/a*np.arctan(a*x))                         # Arctan

# Plot of i.c. & potential
plt.plot(x, np.abs(psi0)**2, label='\u03c8\u2080#2')
plt.plot(x,V, label='V(x)')
plt.legend()
print("Total Probability: ", np.sum(np.abs(psi0)**2)*dx)
# Out:
# Total Probability:  [1.]
# Total Probability:  [1.]

# %%
## SOLVE EQUATION ##

# define storage 
storage = pde.MemoryStorage() # for movie
file_storage = pde.FileStorage(filename=f'./Data/Simulations/Quantum_Osc2_w_{A}.h5') # dataset

# simulation time and step (1e-6 and 1e-5 seems to work, more testing needed to se if less can be used)
t_range = 20
dt_sim = 1e-5

# points to store to file
N_t_writing = 1000 # can be changed if more points are needed
dt_writing = t_range/N_t_writing

# points to use in animation 
N_t_anim = 500 # this is enough do not change it 
dt_anim = t_range/N_t_anim


solver = pde.ExplicitSolver(eq, scheme="runge-kutta", adaptive=False)
controller = pde.Controller(solver, t_range=t_range, tracker=['progress', storage.tracker(interval=dt_anim), file_storage.tracker(interval=dt_writing)])
_ = controller.run(initial_state, dt=dt_sim)
# Out:
#   0%|          | 0/20.0 [00:00<?, ?it/s]
# Initializing:   0%|          | 0/20.0 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-d0c3af9645ab> in <cell line: 22>()
#      20 solver = pde.ExplicitSolver(eq, scheme="runge-kutta", adaptive=False)
#      21 controller = pde.Controller(solver, t_range=t_range, tracker=['progress', storage.tracker(interval=dt_anim), file_storage.tracker(interval=dt_writing)])
# ---> 22 _ = controller.run(initial_state, dt=dt_sim)
#      23
#
# ~/venv/lib/python3.8/site-packages/pde/solvers/controller.py in run(self, state, dt)
#     162         # initialize the stepper
#     163         jit_count_init = numba.JIT_COUNT
# --> 164         stepper = self.solver.make_stepper(state=state, dt=dt)
#     165         self.diagnostics["jit_count"] = {
#     166             "make_stepper": numba.JIT_COUNT - jit_count_init
#
# ~/venv/lib/python3.8/site-packages/pde/solvers/explicit.py in make_stepper(self, state, dt)
#     463                 fixed_stepper = self._make_fixed_euler_stepper(state, dt)
#     464             elif self.scheme in {"runge-kutta", "rk", "rk45"}:
# --> 465                 fixed_stepper = self._make_rk45_stepper(state, dt)
#     466             else:
#     467                 raise ValueError(f"Explicit scheme `{self.scheme}` is not supported")
#
# ~/venv/lib/python3.8/site-packages/pde/solvers/explicit.py in _make_rk45_stepper(self, state, dt)
#     226             )
#     227
# --> 228         rhs = self._make_pde_rhs(state, backend=self.backend)
#     229         self.info["stochastic"] = False
#     230         self.info["adaptive"] = False
#
# ~/venv/lib/python3.8/site-packages/pde/solvers/base.py in _make_pde_rhs(self, state, backend)
#     115             )
#     116
# --> 117         rhs = self.pde.make_pde_rhs(state, backend=backend)
#     118
#     119         if hasattr(rhs, "_backend"):
#
# ~/venv/lib/python3.8/site-packages/pde/pdes/base.py in make_pde_rhs(self, state, backend)
#     230         if backend == "auto":
#     231             try:
# --> 232                 rhs = self._make_pde_rhs_numba_cached(state)
#     233             except NotImplementedError:
#     234                 backend = "numpy"
#
# ~/venv/lib/python3.8/site-packages/pde/pdes/base.py in _make_pde_rhs_numba_cached(self, state)
#     207
#     208         if check_implementation:
# --> 209             self.check_rhs_consistency(state, rhs_numba=rhs)
#     210
#     211         return rhs  # type: ignore
#
# ~/venv/lib/python3.8/site-packages/pde/pdes/base.py in check_rhs_consistency(self, state, t, tol, rhs_numba)
#     147         """
#     148         # obtain evolution rate from the numpy implementation
# --> 149         res_numpy = self.evolution_rate(state.copy(), t).data
#     150         if not np.all(np.isfinite(res_numpy)):
#     151             self._logger.warning(
#
# ~/venv/lib/python3.8/site-packages/pde/pdes/pde.py in evolution_rate(self, state, t)
#     457         if isinstance(state, DataFieldBase):
#     458             # state is a single field
# --> 459             result.data[:] = cache["rhs_funcs"][0](state.data, t)
#     460
#     461         elif isinstance(state, FieldCollection):
#
# ~/venv/lib/python3.8/site-packages/pde/pdes/pde.py in rhs_func(*args)
#     320             bc_args = NumbaDict()  # args for differential operators
#     321             bc_args["t"] = args[-1]  # pass time to differential operators
# --> 322             return func_inner(*args, None, bc_args, *extra_args)  # type: ignore
#     323
#     324         return rhs_func
#
# <lambdifygenerated-4> in _lambdifygenerated(psi, t, none, bc_args, x)
#       1 def _lambdifygenerated(psi, t, none, bc_args, x):
# ----> 2     return 1j*(-0.5*psi*x**2 - psi*arctan(x, none, bc_args) + 0.5*laplace(psi, none, bc_args))
#
# TypeError: arctan() takes from 1 to 2 positional arguments but 3 were given

# %%
## APPEND X DATA TO CREATED FILE ## 

file = h5py.File(f'./Data/Simulations/Quantum_Osc2_w_{A}.h5', 'a')
file.create_dataset('x', data=x)
file.close()

# %%
## PLOT SOLUTIONS ##

pde.plot_kymograph(storage, scalar='norm_squared')

# %%
## CREATE MOVIE ## 

pde.movie(storage, 'test3.mov', plot_args={'scalar':'norm_squared'}) # TODO: ADD LABELS
# Out:
# 100%|██████████| 501/501 [01:22<00:00,  6.07it/s]

# %%
## VISUALIZE MOVIE ## (not working on deepnote)

Video('test3.mov')
# Out:
# <video src="test3.mov" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=964d390d-0269-41ab-86ee-4ee3752d1778' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
